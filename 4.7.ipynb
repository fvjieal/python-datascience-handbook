# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  2.,   9.,  59., 159., 245., 293., 165.,  52.,  11.,   5.]),
#  array([-3.69139541, -2.95912626, -2.2268571 , -1.49458795, -0.7623188 ,
#         -0.03004965,  0.7022195 ,  1.43448866,  2.16675781,  2.89902696,
#          3.63129611]),
#  <a list of 10 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00285434, 0.        , 0.00285434, 0.00285434, 0.00570868,
#         0.00856301, 0.01712603, 0.01998036, 0.01712603, 0.04852374,
#         0.04852374, 0.04852374, 0.0456694 , 0.09133881, 0.09704749,
#         0.13986255, 0.15698858, 0.20551232, 0.19124063, 0.16555159,
#         0.25974474, 0.20551232, 0.20836666, 0.18553196, 0.12273653,
#         0.14842557, 0.11417351, 0.08563013, 0.06564977, 0.0228347 ,
#         0.05137808, 0.02568904, 0.01427169, 0.01427169, 0.00570868,
#         0.        , 0.        , 0.00285434, 0.00285434, 0.00285434]),
#  array([-4.02766381, -3.67731986, -3.3269759 , -2.97663194, -2.62628798,
#         -2.27594403, -1.92560007, -1.57525611, -1.22491215, -0.87456819,
#         -0.52422424, -0.17388028,  0.17646368,  0.52680764,  0.87715159,
#          1.22749555,  1.57783951,  1.92818347,  2.27852743,  2.62887138,
#          2.97921534,  3.3295593 ,  3.67990326,  4.03024721,  4.38059117,
#          4.73093513,  5.08127909,  5.43162305,  5.781967  ,  6.13231096,
#          6.48265492,  6.83299888,  7.18334283,  7.53368679,  7.88403075,
#          8.23437471,  8.58471867,  8.93506262,  9.28540658,  9.63575054,
#          9.9860945 ]),
#  <a list of 1 Patch objects>)

# %%
counts, bin_edge = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 11 218 538 217  16]

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
from scipy.stats import gaussian_kde

# 配列サイズを[N次元、Nサンプル]に揃える
data = np.vstack([x, y])
kde = gaussian_kde(data)

# 均一なグリッド上で評価する
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# 結果をイメージして表示する
plt.imshow(Z.reshape(Xgrid.shape),
         origin='lower', aspect='auto',
         extent=[-3.5, 3.5, -6, 6],
         cmap='Blues')
cb = plt.colorbar()

cb.set_label("density")
