# %%
plt.figure() # figureを作成する

# 最初のグラフを作成し、現在の座標軸に設定する
# (rows, columns, panel number)
plt.subplot(2, 1, 1) 
plt.plot(x, np.sin(x))

# 二番目のグラフを作成し、現在の座標軸に設定する
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
# 最初にプロットのグリッドを作成する
# axは、2つの座標軸オブジェクトの配列
fig, ax = plt.subplots(2)

# オブジェクトのplot()メソッドをコールする
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))
